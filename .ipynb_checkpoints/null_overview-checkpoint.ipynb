# %% [markdown]
# #### Objective:
# Take a look at the raw data to start some basic clean up, specifically look at the prescence of null values that apply to our question of locating opportunities for renewable energy production.

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import data
gpp_data = pd.read_csv('./data/global_power_plant_database.csv')
gpp_data.head()
# Out:
# C:\Users\farrj\AppData\Local\Temp\ipykernel_37680\3648764891.py:2: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   gpp_data = pd.read_csv('./data/global_power_plant_database.csv')
#   country country_long                                              name  \
# 0     AFG  Afghanistan      Kajaki Hydroelectric Power Plant Afghanistan
# 1     AFG  Afghanistan                                      Kandahar DOG
# 2     AFG  Afghanistan                                      Kandahar JOL
# 3     AFG  Afghanistan     Mahipar Hydroelectric Power Plant Afghanistan
# 4     AFG  Afghanistan  Naghlu Dam Hydroelectric Power Plant Afghanistan
#
#       gppd_idnr  capacity_mw  latitude  longitude primary_fuel other_fuel1  \
# 0  GEODB0040538         33.0    32.322    65.1190        Hydro         NaN
# 1    WKS0070144         10.0    31.670    65.7950        Solar         NaN
# ...

# %%
# import part of README file60-98
file_name = './data/README.txt'
with open(file_name, 'r', encoding= 'utf-8') as f:
    lines = f.readlines()
    
for line in lines[60:98]:
    print(line)
# Out:
# Fields:
#
#
#
# 	- `country` (text): 3 character country code corresponding to the ISO 3166-1 alpha-3 specification [5]
#
# 	- `country_long` (text): longer form of the country designation
#
# 	- `name` (text): name or title of the power plant, generally in Romanized form
#
# 	- `gppd_idnr` (text): 10 or 12 character identifier for the power plant
#
# 	- `capacity_mw` (number): electrical generating capacity in megawatts
#
# 	- `latitude` (number): geolocation in decimal degrees; WGS84 (EPSG:4326)
#
# 	- `longitude` (number): geolocation in decimal degrees; WGS84 (EPSG:4326)
#
# 	- `primary_fuel` (text): energy source used in primary electricity generation or export
#
# 	- `other_fuel1` (text): energy source used in electricity generation or export
#
# 	- `other_fuel2` (text): energy source used in electricity generation or export
#
# 	- `other_fuel3` (text): energy source used in electricity generation or export
#
# ...

# %%
gpp_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34936 entries, 0 to 34935
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   country                         34936 non-null  object
#  1   country_long                    34936 non-null  object
#  2   name                            34936 non-null  object
#  3   gppd_idnr                       34936 non-null  object
#  4   capacity_mw                     34936 non-null  float64
#  5   latitude                        34936 non-null  float64
#  6   longitude                       34936 non-null  float64
#  7   primary_fuel                    34936 non-null  object
#  8   other_fuel1                     1944 non-null   object
#  9   other_fuel2                     276 non-null    object
#  10  other_fuel3                     92 non-null     object
#  11  commissioning_year              17447 non-null  float64
# ...

# %%
gpp_data.geolocation_source.value_counts()
# Out:
# geolocation_source
# U.S. Energy Information Administration                                                 9789
# Wiki-Solar                                                                             3690
# WRI                                                                                    2869
# UK Renewable Energy Planning Database                                                  2582
# Open Power System Data                                                                 2389
# Agência Nacional de Energia Elétrica (Brazil)                                          2338
# GEODB                                                                                  1788
# UNFCCC CDM Registry                                                                    1598
# Industry About                                                                         1327
# CARMA                                                                                  1295
# ...

# %%
gpp_data.generation_data_source.value_counts()
# Out:
# generation_data_source
# U.S. Energy Information Administration                                       9715
# JRC-PPDB-OPEN                                                                 509
# Central Electricity Authority                                                 437
# Australia Clean Energy Regulator                                              269
# Open Development Vietnam                                                      156
# Guatemala Energy Data Visualization Center at Universidad Rafael Landivar      72
# ENTSOE                                                                         58
# Egyptian Electricity Holding Company                                           39
# Venezuela Electricity Sector                                                   36
# Open Development Myanmar                                                       30
# Peru Ministry of Energy and Mines                                              30
# ...

# %% [markdown]
# To better view null values, drop the following columns:
# - country: redundant information, i.e. same info as country_long
# - name: will be using gppd_indr as identifier for this visualization
# - latitude: unecessary info for this analysis
# - longitude: unecessary info for this analysis
# - url: unecessary info for this analysis
# - geolocation_source: unecessary info for this analysis
# - wepp_id: will be using gppd_indr as identifier for this visualization
# - generation_data_source: unecessary info for this analysis

# %%
remove_cols = ['country', 'name', 'latitude', 'longitude', 'url', 'geolocation_source', 'wepp_id', 'generation_data_source']
gpp_removed = gpp_data.drop(columns= remove_cols)
gpp_removed.head()
# Out:
#   country_long     gppd_idnr  capacity_mw primary_fuel other_fuel1  \
# 0  Afghanistan  GEODB0040538         33.0        Hydro         NaN
# 1  Afghanistan    WKS0070144         10.0        Solar         NaN
# 2  Afghanistan    WKS0071196         10.0        Solar         NaN
# 3  Afghanistan  GEODB0040541         66.0        Hydro         NaN
# 4  Afghanistan  GEODB0040534        100.0        Hydro         NaN
#
#   other_fuel2 other_fuel3  commissioning_year owner      source  ...  \
# 0         NaN         NaN                 NaN   NaN       GEODB  ...
# 1         NaN         NaN                 NaN   NaN  Wiki-Solar  ...
# 2         NaN         NaN                 NaN   NaN  Wiki-Solar  ...
# 3         NaN         NaN                 NaN   NaN       GEODB  ...
# 4         NaN         NaN                 NaN   NaN       GEODB  ...
#
#    estimated_generation_gwh_2013  estimated_generation_gwh_2014  \
# 0                         123.77                         162.90
# ...

# %%
sns.heatmap(gpp_removed.isnull(), cmap= 'viridis')
plt.show()

# %% [markdown]
# There are large chunks of missing data in several columns of interest in our dataset.
# - Are there more columns that can be discarded?
# - Discard rows with nulls or fill in a value?
#     - Fill in with 0 or some other value?
